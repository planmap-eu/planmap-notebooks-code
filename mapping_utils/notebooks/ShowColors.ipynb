# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib._color_data as mcd
import matplotlib.patches as mpatch
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tabfile = "/home/luca/Documenti-local/notebooks.git/mapping/maptable_3_classes.csv"
import pandas as pd
newtab = pd.DataFrame.from_csv(tabfile, sep=",", index_col=None )
figure(figsize=[0.5, 6])

ax = gca()
red = newtab[ ["Extended_Label", "R","G", "B"] ]



for j, row in red.iterrows():
    label, r,g,b =row.values
    
    col = np.array([r,g,b]) 
    col = col / 255.0
    
    
    r1 = mpatch.Rectangle((0, j), 1, 1, color=col)
    txt = ax.text(2, j+.5, '  ' + label, va='center', fontsize=10,        )
    ax.add_patch(r1)
    ax.axhline(j, color='k')
# Out:
# /usr/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
tabfile = "/data/planmap/Planmap/DATA/moon/PM-MOO-MS-Apollo_01/vector/tmp_apollo_vector/units_APollo.xlsx"
import pandas as pd
import numpy as np
newtab = pd.read_excel(tabfile)
newtab

newtab[newtab.Topology == "Polygon"]


rgbs = newtab.RGB.values
out=[]
for color in rgbs:
    if type(color) != str:
        out.append([np.nan, np.nan, np.nan])
        continue
        
    color = color.replace("(", "").replace(")", "").strip()
    
    r,g,b = color.split(",")
    r = np.int(r)
    g = np.int(g)
    b = np.int(b)
    
    out.append([r,g,b])
    
out = np.ascontiguousarray(out)
out
# Out:
# array([[  0.,   0.,   0.],
#        [ nan,  nan,  nan],
#        [  0.,   0.,   0.],
#        [  0.,   0.,   0.],
#        [168.,   0.,   0.],
#        [ 38., 115.,   0.],
#        [255.,  85.,   0.],
#        [255., 255.,   0.],
#        [100., 235.,  33.],
#        [197.,  82., 230.],
#        [233., 176., 240.],
#        [ 56., 221., 200.],
#        [200., 240., 255.],
#        [130., 166., 208.],
#        [ 40.,  69., 181.],
#        [ 96., 129., 255.],
#        [212., 197., 150.],
#        [239., 176., 134.],
#        [127.,  50.,  11.],
#        [176.,  99.,  48.],
#        [182., 159., 148.],
#        [123., 118., 111.]])

# %%
newtab["R"] = out[:,0]
newtab["G"] = out[:,1]
newtab["B"] = out[:,2]

# %%
figure(figsize=[0.5, 6])

ax = gca()
red = newtab[ ["Unit_Name", "R","G", "B"] ]



for j, row in red.iterrows():
    label, r,g,b =row.values
    
    col = np.array([r,g,b]) 
    col = col / 255.0
    
    
    r1 = mpatch.Rectangle((0, j), 1, 1, color=col)
    txt = ax.text(2, j+.5, '  ' + label, va='center', fontsize=10,        )
    ax.add_patch(r1)
    ax.axhline(j, color='k')

# %%
# Out:
# /usr/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   This is separate from the ipykernel package so we can avoid doing imports until
